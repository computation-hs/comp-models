# %%
# Pruebas para dibujar DFAs en Python.
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

# %%
def draw_graph(graph, labels=None, graph_layout='shell',
               node_size=1600, node_color='white', node_alpha=1,
               node_text_size=12,
               edge_color='black', edge_alpha=1, edge_tickness=1.5,
               edge_text_pos=0.3, arrows=True,
               text_font='sans-serif'):

    # create networkx graph
    G=nx.DiGraph()

    # add edges
    for edge in graph:
        G.add_edge(edge[0], edge[1])

    # these are different layouts for the network you may try
    # shell seems to work best
    if graph_layout == 'spring':
        graph_pos=nx.spring_layout(G)
    elif graph_layout == 'spectral':
        graph_pos=nx.spectral_layout(G)
    elif graph_layout == 'random':
        graph_pos=nx.random_layout(G)
    else:
        graph_pos=nx.shell_layout(G)

    # draw graph
    nx.draw_networkx_nodes(G,graph_pos,node_size=node_size, 
                           alpha=node_alpha, node_color=node_color)
    nx.draw_networkx_edges(G,graph_pos,width=edge_tickness,
                           alpha=edge_alpha,edge_color=edge_color, arrows=arrows)
    nx.draw_networkx_labels(G, graph_pos,font_size=node_text_size,
                            font_family=text_font)

    # show graph
    plt.show()

# %%
# draw example
graph = [(20, 21),(21, 22),(22, 23), (23, 24),(24, 25), (25, 20),(23,20),(21,24)]
draw_graph(graph, node_alpha=1)

# %%
graph = graph + [(23,25)]
draw_graph(graph, node_alpha=0.2)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-69707539af52> in <module>()
# ----> 1 nx.draw_graphviz(graph)
#
# /usr/lib/python2.7/dist-packages/networkx/drawing/nx_pylab.pyc in draw_graphviz(G, prog, **kwargs)
#     879 def draw_graphviz(G, prog="neato", **kwargs):
#     880     """Draw networkx graph with graphviz layout."""
# --> 881     pos=nx.drawing.graphviz_layout(G,prog)
#     882     draw(G,pos,**kwargs)
#     883
#
# /usr/lib/python2.7/dist-packages/networkx/drawing/nx_agraph.pyc in graphviz_layout(G, prog, root, args)
#     227
#     228     """
# --> 229     return pygraphviz_layout(G,prog=prog,root=root,args=args)
#     230
#     231 def pygraphviz_layout(G,prog='neato',root=None, args=''):
#
# /usr/lib/python2.7/dist-packages/networkx/drawing/nx_agraph.pyc in pygraphviz_layout(G, prog, root, args)
# ...
