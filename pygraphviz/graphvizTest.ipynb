# %%
from graphviz import Digraph

# %%
# Defines a directed graph.
# Creates nodes and edges.
dot = Digraph(format='png')

dot.node('A','Start')
dot.node('B','Even')
dot.node('C','Odd')

dot.edges(['AB','AC','BC','CB'])

# Prints the source code.
print(dot.source)
dot.render('graph/test', view=True)
# Out:
# digraph {
# 	A [label=Start]
# 	B [label=Even]
# 	C [label=Odd]
# 		A -> B
# 		A -> C
# 		B -> C
# 		C -> B
# }
# 'graph/test.png'

# %%
# Inserts the image.
from IPython.display import Image
Image(filename='graph/test.png')

# %%
# Changes the image
dot.node_attr.update(fillcolor='palegreen')
print(dot.source)
Image(filename='graph/test.png')
# Out:
# digraph {
# 	node [fillcolor=palegreen]
# 		A [label=Start]
# 		B [label=Even]
# 		C [label=Odd]
# 			A -> B
# 			A -> C
# 			B -> C
# 			C -> B
# }
